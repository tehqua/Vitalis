# %%
import sys
import os
from IPython.display import Markdown, display
sys.path.append(os.path.abspath("../../.."))

# %%
from agents.orchestrator import MedicalChatbotAgent

agent = MedicalChatbotAgent()

result = agent.process_message(
    patient_id="Adam631_Cronin387_aff8f143-2375-416f-901d-b0e4c73e3e58",
    text_input="I have a headache"
)
# Out:
# INFO:agents.orchestrator.agent:State graph compiled successfully
# INFO:agents.orchestrator.agent:MedicalChatbotAgent initialized successfully
# INFO:agents.orchestrator.agent:Processing message for patient Adam631_Cronin387_aff8f143-2375-416f-901d-b0e4c73e3e58 | Text: True | Audio: False | Image: False
# INFO:agents.orchestrator.nodes:Node: input_router
# INFO:agents.orchestrator.nodes:Routing decision: reasoning
# INFO:agents.orchestrator.nodes:Node: reasoning_node
# INFO:agents.orchestrator.nodes:Calling LLM for reasoning
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# INFO:agents.orchestrator.nodes:LLM response generated: 736 characters
# INFO:agents.orchestrator.nodes:Node: safety_check
# INFO:agents.orchestrator.nodes:Safety check passed
# INFO:agents.orchestrator.agent:Message processed successfully | Session: 535ea005-bfe1-441b-81fe-c726a3ea3b77

# %%
display(Markdown(result["response"]))
# Out:
# Hello! I understand you're experiencing a headache. I'm here to help you understand it better and offer some guidance.
# To help me understand your headache, could you tell me:
# *   **Where is the headache located?** (e.g., all over, one side, back of head)
# *   **What does the headache feel like?** (e.g., throbbing, pressure, stabbing)
# *   **How severe is the headache on a scale of 1 to 10, with 1 being mild and 10 being the worst pain imaginable?**
# *   **When did the headache start?**
# *   **Are there any other symptoms accompanying the headache?** (e.g., nausea, vomiting, sensitivity to light or sound, vision changes)
# In the meantime, I can use our skin analysis tool to help understand your skin condition, if you would like.
# MEDICAL DISCLAIMER: This information is for educational purposes only and is not a substitute for professional medical advice, diagnosis, or treatment. Always consult your healthcare provider for medical concerns.
